# %% [markdown]
# #Simple MNIST convnet

# %%
# Setup
import numpy as np
import keras
from keras import layers

# %%
# Prepare the data
# Model / data parameters
num_classes = 10
input_shape = (28, 28, 1)

# Load the data and split it between train and test sets
(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()

# Scale images to the [0, 1] range
x_train = x_train.astype("float32") / 255
x_test = x_test.astype("float32") / 255
# Make sure images have shape (28, 28, 1)
x_train = np.expand_dims(x_train, -1)
x_test = np.expand_dims(x_test, -1)
print("x_train shape:", x_train.shape)
print(x_train.shape[0], "train samples")
print(x_test.shape[0], "test samples")


# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step
# x_train shape: (60000, 28, 28, 1)
# 60000 train samples
# 10000 test samples

# %%
model = keras.Sequential(
    [
        keras.Input(shape=input_shape),
        layers.Conv2D(32, kernel_size=(3, 3), activation="relu"),
        layers.MaxPooling2D(pool_size=(2, 2)),
        layers.Conv2D(64, kernel_size=(3, 3), activation="relu"),
        layers.MaxPooling2D(pool_size=(2, 2)),
        layers.Flatten(),
        layers.Dropout(0.5),
        layers.Dense(num_classes, activation="softmax"),
    ]
)

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_1 (Conv2D)           (None, 26, 26, 32)        320
#
#  max_pooling2d (MaxPooling2  (None, 13, 13, 32)        0
#  D)
#
#  conv2d_2 (Conv2D)           (None, 11, 11, 64)        18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 5, 5, 64)          0
#  g2D)
#
#  flatten (Flatten)           (None, 1600)              0
#
#  dropout (Dropout)           (None, 1600)              0
#
#  dense (Dense)               (None, 10)                16010
#
# =================================================================
# Total params: 34826 (136.04 KB)
# Trainable params: 34826 (136.04 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Train the model ## Reduced batch_size and epochs to reduce training time
batch_size = 12
epochs = 5

model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, validation_split=0.1)
# Out:
# Epoch 1/5
# 4500/4500 [==============================] - 24s 5ms/step - loss: 0.1780 - accuracy: 0.9451 - val_loss: 0.0497 - val_accuracy: 0.9880
# Epoch 2/5
# 4500/4500 [==============================] - 23s 5ms/step - loss: 0.0745 - accuracy: 0.9761 - val_loss: 0.0347 - val_accuracy: 0.9908
# Epoch 3/5
# 4500/4500 [==============================] - 23s 5ms/step - loss: 0.0598 - accuracy: 0.9814 - val_loss: 0.0339 - val_accuracy: 0.9912
# Epoch 4/5
# 4500/4500 [==============================] - 23s 5ms/step - loss: 0.0511 - accuracy: 0.9836 - val_loss: 0.0331 - val_accuracy: 0.9915
# Epoch 5/5
# 4500/4500 [==============================] - 23s 5ms/step - loss: 0.0455 - accuracy: 0.9855 - val_loss: 0.0342 - val_accuracy: 0.9918

# %%
# Evaluate the trained model
score = model.evaluate(x_test, y_test, verbose=0)
print("Test loss:", score[0])
print("Test accuracy:", score[1])
# Out:
# Test loss: 0.029299428686499596
# Test accuracy: 0.9901000261306763
